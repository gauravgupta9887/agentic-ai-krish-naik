# %% [markdown]
# ### Model Integration with OpenAI, Google Geimini and GROQ

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain_openai import ChatOpenAI

custom_llm = ChatOpenAI(
    model="gemma-local",
    api_key=os.getenv("CHAT_API_KEY"),
    base_url=os.getenv("CHAT_API_BASE_URL"),
    temperature=0,
    verbose=True
)

# %%
custom_llm.invoke("Who was the first person to walk on the moon?")
# Out:
# AIMessage(content='The first person to walk on the moon was **Neil Armstrong**. He stepped onto the lunar surface on July 20, 1969, during the Apollo 11 mission.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 40, 'prompt_tokens': 24, 'total_tokens': 64, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'hosted_vllm/gemma-local', 'system_fingerprint': None, 'id': 'chatcmpl-a64d2ed1d7fe5b08', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e9c8c-97e3-7ea0-84bd-493daf419b5c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 24, 'output_tokens': 40, 'total_tokens': 64, 'input_token_details': {}, 'output_token_details': {}})

# %%
response = custom_llm.invoke("Why does parrot talk?")
response.content
# Out:
# 'Parrots do not have vocal cords like humans do. Instead, they have a specialized organ called a **syrinx**, located at the base of their windpipe. By controlling the muscles around the syrinx and manipulating their tongue and throat, they can mimic the sounds they hear around them.\n\nBut the "how" is only half the story. The "why" is based on social behavior and survival. Here are the primary reasons why parrots talk:\n\n### 1. Social Bonding (The "Flock" Mentality)\nIn the wild, parrots are highly social animals that live in flocks. They use a variety of calls to identify their family members, warn others of danger, and maintain social bonds. \n\nWhen a parrot is kept as a pet, **the humans become their "flock."** To fit in and bond with their new social group, parrots mimic the sounds that the humans make. By copying your words, they are essentially trying to "speak the language" of their family to feel accepted and connected.\n\n### 2. Attention and Reward\nParrots are very inte
# ...

# %%
for chunk in custom_llm.stream("Why does parrot talk?"):
    print(chunk.content, end="!", flush=True)
# Out:
# Par!rots! do! not! have! vocal! cords! like! humans! do!.! Instead!,! they! have! a! specialized! organ! called! a! **!s!yr!inx!**,! located! at! the! base! of! their! wind!pipe!.! By! controlling! the! muscles! around! the! sy!rin!x! and! manipulating! their! tongue! and! throat!,! they! can! mimic! the! sounds! they! hear! around! them!.!
#
# !But! the! "!how!"! is! only! half! the! story!.! The! "!why!"! is! based! on! social! behavior! and! survival!.! Here! are! the! primary! reasons! why! parrots! talk!:!
#
# !###! !1!.! Social! Bonding! (!The! "!Fl!ock!"! Ment!ality!)!
# !In! the! wild!,! parrots! are! highly! social! animals! that! live! in! flocks!.! They! use! a! variety! of! calls! to! identify! their! family! members!,! warn! others! of! danger!,! and! maintain! social! bonds!.! !
#
# ...

# %%
response = custom_llm.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"                   
])

# %%
response
# Out:
# [AIMessage(content="Parrots have colorful feathers for a combination of biological, evolutionary, and social reasons. While it may seem counterintuitive for a bird to be bright and easy for predators to spot, these colors serve several critical functions.\n\nHere are the primary reasons why parrots are so colorful:\n\n### 1. Camouflage (Disruptive Coloration)\nIt seems contradictory, but bright colors can actually be a form of camouflage. Most parrots live in tropical rainforests, which are incredibly vibrant environments. \n*   **Dappled Light:** In a canopy filled with bright green leaves, colorful flowers, and shafts of sunlight, a bright green or red bird blends in better than a solid dark-colored bird would.\n*   **Breaking the Outline:** Bold patterns and bright colors break up the bird's silhouette, making it harder for a predator (like a hawk) to recognize the shape of a parrot against the chaotic background of the jungle.\n\n### 2. Social Communication and Mating\nParrots ar
# ...

# %%
custom_llm.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"],
    config={"max_concurrency": 2})
# Out:
# [AIMessage(content='Parrots have colorful feathers for a combination of biological, evolutionary, and environmental reasons. While it may seem counterintuitive for a bird to be bright and "easy to see," these colors serve several critical functions:\n\n### 1. Camouflage (The "Hidden in Plain Sight" Effect)\nIt seems paradoxical, but bright colors are often the best camouflage in a tropical rainforest. \n*   **Dappled Light:** Rainforest canopies are filled with bright green leaves, vivid exotic flowers, and shafts of intense sunlight. A bright red or yellow bird blends into the colorful foliage and flowers, making it harder for predators (like hawks) to spot them from above.\n*   **Disruptive Coloration:** Bold patterns break up the outline of the bird\'s body, making it difficult for a predator to tell where the bird begins and ends against a busy background.\n\n### 2. Social Communication and Mating\nLike many animals, parrots use their appearance to communicate with others of thei
# ...
